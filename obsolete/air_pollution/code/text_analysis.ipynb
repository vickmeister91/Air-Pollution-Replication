# %%
import pandas as pd
import numpy as np
import tqdm
import os

import logging
logging.basicConfig(format='%(asctime)s [%(levelname)s] %(message)s',
                    level=logging.INFO)

import nltk
from nltk import FreqDist

from fuzzywuzzy import fuzz
from bs4 import BeautifulSoup
import lxml
import re

# %%
def cleaner(txt_file):
    
    text = txt_file
    text = re.sub(r"(&[a-zA-Z]*;)", " ", text)  # the txt files had some unwanted text like &rsquo; this line removes such text
    text = text.lower()
    
    # remove punctuation and numbers from the string
    punctuations = '''!()[]{};:'"\,<->/?@#$%^&*_~=+`|0123456789'''  # removing punctuations except hyphens
    
    
    for x in text.lower(): 
        if x in punctuations: 
            text = text.replace(x, "")

            
    
    text = text.replace(" st ", " ")
    text = text.replace(" nd ", " ")
    text = text.replace(" rd ", " ")
    text = text.replace(" th ", " ")
    text = text.replace("hellip", " ")
    text = text.replace("rsquo", " ")
    text = text.replace("ldquo", " ")
    text = text.replace("rdquo", " ")
    text = text.replace("ndash", " ")
    text = text.replace("--", " ")
    text = text.replace("\n", " ")
    text = text.replace("\t", " ")
    
    text = text.replace("kshs.", "kshs ")

    
    return text

# %%
df_cases = pd.read_excel("/Users/shashanksingh/Desktop/air_pollution/data/raw_data/Air Pollution Cases_updated 17.10.21.xlsx")

# %%
df_cases = df_cases.drop_duplicates(["Kanoon_ID"], keep = "first")
df_cases = df_cases.reset_index(drop=True)

# %%
root_dir = "/Users/shashanksingh/Desktop/IND_PROJ/water_pollution/Kanoon_html_new_with_air"
text_list_all = []
kanoon_id_list = []

for index in tqdm.trange(len(df_cases)):
    kanoon_id = int(df_cases["Kanoon_ID"][index])

    path = root_dir + "/" + str(kanoon_id) + ".html"      

    f = open(path, "r").read()
    soup = BeautifulSoup(f, 'lxml')
    
    # removing first 20
    text_list = cleaner(soup.findAll("div", {"class": "judgments"})[0].text).split()[20:]
    
    text_ = " ".join(ele for ele in text_list)
    
    text_list_all.append(text_)
    kanoon_id_list.append(kanoon_id)
# Out:
# 100%|██████████| 1910/1910 [05:29<00:00,  5.80it/s]

# %%
from nltk.corpus import stopwords

final_stopwords_list = stopwords.words('english')

# %%
final_stopwords_list = [cleaner(ele) for ele in final_stopwords_list]

final_stopwords_list = final_stopwords_list + ["of","in","the","shall","will","on","to"]

# %%
#import the TfidfVectorizer from Scikit-Learn.
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words= final_stopwords_list,ngram_range = (3,3))
transformed_documents = vectorizer.fit_transform(text_list_all)

# %%
transformed_documents_as_array = transformed_documents.toarray()

# %%
len(transformed_documents_as_array)
# Out:
# 1910

# %%
feature_names = vectorizer.get_feature_names()

# %%
df = pd.DataFrame(transformed_documents_as_array,
                 index=list(df_cases["Kanoon_ID"]),
                 columns=feature_names)

# %%
list_cols = feature_names

list_mean = []

for ele in tqdm.tqdm(list_cols):
    
    mean_score = df[ele].mean()
    
    list_mean.append(mean_score)
# Out:
# 100%|██████████| 2446760/2446760 [07:36<00:00, 5354.56it/s]

# %%
df_scores = pd.DataFrame()

# %%
df_scores["phrase"] = list_cols
df_scores["mean_score"] = list_mean

# %%
df_scores["mean_score"].max()
# Out:
# 0.019531341537394338

# %%
df_scores["mean_score"].min()
# Out:
# 3.4517589690494873e-07

# %%
df_scores = df_scores.sort_values(["mean_score"], ascending=False)

# %%
df_scores.head(50)
# Out:
#                                phrase  mean_score
# 1664359       pollution control board    0.019531
# 2122725       state pollution control    0.011684
# 1705359  prevention control pollution    0.010385
# 529159          control pollution act    0.009576
# 1213057     learned counsel appearing    0.008518
# 90733          air prevention control    0.006804
# 2377093      water prevention control    0.006534
# 1408082       national green tribunal    0.006312
# 1213342    learned counsel petitioner    0.006267
# 392127            civil writ petition    0.006111
# 1020187             honble mr justice    0.005622
# 1020055             honble high court    0.004976
# 202700     article constitution india    0.004903
# 1020317          honble supreme court    0.004636
# 547904        counsel appearing state    0.004558
# 2012620        section air prevention    0.004508
# 1567650              patna high court    0.004467
# 1401352        nadu pollution control    0.004115
# 1020520         honourable mr justice    0.004113
# 2207454          tamil nadu pollution    0.004084
# 1806455     rajasthan state pollution    0.004056
# 1168064     karnataka state pollution    0.003981
# 781637     environment protection act    0.003909
# 1214213        learned senior counsel    0.003877
# 1214237          learned single judge    0.003854
# 996937          heard learned counsel    0.003846
# 2020487      section water prevention    0.003839
# 2055937             show cause notice    0.003646
# 1029244             httpwww judis nic    0.003511
# 1510203            order dated passed    0.003418
# 547756    counsel appearing applicant    0.003263
# 1171581        kerala state pollution    0.003208
# 1073747             indian penal code    0.003155
# 823459              exhibit true copy    0.003129
# 536103                coram honble mr    0.003123
# 414409        code criminal procedure    0.003121
# 2343839            versus state bihar    0.003087
# 1428030             next date hearing    0.003021
# 381460      chief judicial magistrate    0.003021
# 1213347   learned counsel petitioners    0.002982
# 2290822             two sureties like    0.002969
# 1626330      petitioners versus state    0.002955
# 2189345          sureties like amount    0.002944
# 2429848           writ petition filed    0.002912
# 1241401      like amount satisfaction    0.002912
# 2243771         thousand two sureties    0.002835
# 536114            coram honourable mr    0.002805
# 90392           air pollution control    0.002773
# 1619198       petitioner versus state    0.002771
# 1011713                 high court cr    0.002761

# %%
df_scores[50:100]
# Out:
#                                phrase  mean_score
# 2430092              writ petition ms    0.002723
# 2347648              vide order dated    0.002719
# 1709885    principles natural justice    0.002716
# 2366432            vs rajasthan state    0.002611
# 2020473             section water act    0.002584
# 2430208             writ petition pil    0.002579
# 25601              act air prevention    0.002535
# 2021374         sections indian penal    0.002534
# 1772726    public interest litigation    0.002530
# 2013565         section code criminal    0.002522
# 1662331             pollution act air    0.002492
# 2012607               section air act    0.002483
# 2314932        uploaded downloaded wp    0.002467
# 245150           bail furnishing bail    0.002461
# 2155156       subject conditions laid    0.002420
# 560375                  court cwjc dt    0.002404
# 1011722               high court cwjc    0.002404
# 2347447             vide letter dated    0.002389
# 276717          bihar state pollution    0.002388
# 474143        conditions laid section    0.002380
# 441142       company conduct business    0.002379
# 2216762              ten thousand two    0.002369
# 1926968   responsible company conduct    0.002367
# 360152      central pollution control    0.002304
# 1361812  ministry environment forests    0.002279
# 476095       conduct business company    0.002278
# 252276      barun district aurangabad    0.002275
# 926658           furnishing bail bond    0.002263
# 553702           country planning act    0.002262
# 482049          connection barun case    0.002251
# 245067                   bail bond rs    0.002224
# 151416      appearance petitioners mr    0.002216
# 1213414    learned counsel respondent    0.002204
# 1664339        pollution control area    0.002204
# 743944       effluent treatment plant    0.002198
# 851368       facts circumstances case    0.002187
# 1055567          impugned order dated    0.002158
# 805317         event arrest surrender    0.002133
# 1567607  patna criminal miscellaneous    0.002125
# 1506816              oral order heard    0.002099
# 2267220         town country planning    0.002087
# 45367            acting chief justice    0.002086
# 1213330       learned counsel parties    0.002083
# 1514432         order passed tribunal    0.002080
# 459097        compliance report dated    0.002052
# 706835           division bench court    0.002050
# 1260524              long term scheme    0.002045
# 459103        compliance report filed    0.002039
# 1662967         pollution act section    0.002037
# 198873                arising ps case    0.002021

# %%
df_scores[100:150]
# Out:
#                                  phrase  mean_score
# 1769706                    ps case year    0.002021
# 345294                  case year thana    0.002021
# 984600        gujarat pollution control    0.002015
# 974783               green tribunal act    0.001996
# 1664497      pollution control measures    0.001992
# 584550   criminal miscellaneous arising    0.001978
# 1363758        miscellaneous arising ps    0.001978
# 560297                    court cr misc    0.001958
# 1921864        respondents coram honble    0.001952
# 2017226                 section ngt act    0.001946
# 2343845          versus state jharkhand    0.001928
# 1512136             order heard learned    0.001918
# 1987908         sangh rajasthan pradesh    0.001914
# 1186421                 laid section cr    0.001911
# 1212934          learned chief judicial    0.001905
# 579652                       cr misc dt    0.001893
# 1015587           himachal pradesh town    0.001887
# 2018982                section said act    0.001886
# 130465      amount satisfaction learned    0.001861
# 1145859       jharkhand state pollution    0.001858
# 2144922             stone crushing unit    0.001845
# 71492       aerial distance certificate    0.001817
# 526295              control board civil    0.001813
# 284711                 board civil writ    0.001813
# 2015249  section environment protection    0.001790
# 1012000           high court judicature    0.001786
# 1768919     provisions water prevention    0.001771
# 41090                   act section air    0.001754
# 1701212           present writ petition    0.001741
# 1957275                 rs ten thousand    0.001738
# 1505697              opposite partys mr    0.001736
# 1561541   partys appearance petitioners    0.001731
# 1505694      opposite partys appearance    0.001731
# 2429773          writ petition disposed    0.001729
# 247768            bangalore north taluk    0.001723
# 766065         engineer water resources    0.001723
# 992077          haryana state pollution    0.001721
# 273794             bhartiya kisan sangh    0.001718
# 1806369     rajasthan pollution control    0.001714
# 1174799           kisan sangh rajasthan    0.001711
# 462209         comprehensive short term    0.001705
# 573459             court tribunal first    0.001705
# 1088293         inferior court tribunal    0.001703
# 2281101         tribunal first instance    0.001702
# 1798072   question relating environment    0.001692
# 1213466           learned counsel state    0.001689
# 2218596                  term long term    0.001682
# 2055259                 short term long    0.001682
# 375732       charge responsible company    0.001676
# 1567516     patilsr uploaded downloaded    0.001668

# %%
df_scores.to_csv("tfidf_scores.csv")
